# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns

# %%
beer_df = pd.read_csv('Data/beer_reviews_BeerAdvocate.csv')
display(beer_df[:1].head())
# Out:
#    brewery_id     brewery_name  review_time  review_overall  review_aroma  \
# 0       10325  Vecchio Birraio   1234817823             1.5           2.0
#
#    review_appearance review_profilename  beer_style  review_palate  \
# 0                2.5            stcules  Hefeweizen            1.5
#
#    review_taste     beer_name  beer_abv  beer_beerid
# 0           1.5  Sausa Weizen       5.0        47986

# %%
## Top 10 beers by Taste
beers_looks_smell = beer_df[['beer_name', 'review_taste']]
beer_looks_smell = beers_looks_smell.groupby('beer_name').aggregate(['max'])
beer_looks_smell = beers_looks_smell.sort_values(by = ['review_taste'],ascending = False).iloc[0:10]
beer_looks_smell
# Out:
#                                beer_name  review_taste
# 417039            Great Lakes Eliot Ness           5.0
# 444369          Uerige Altbier (Classic)           5.0
# 444389          Uerige Altbier (Classic)           5.0
# 739729                       Pumpkin Ale           5.0
# 895174  Stone 06.06.06 Vertical Epic Ale           5.0
# 895180  Stone 06.06.06 Vertical Epic Ale           5.0
# 444384          Uerige Altbier (Classic)           5.0
# 895184  Stone 06.06.06 Vertical Epic Ale           5.0
# 739719                       Pumpkin Ale           5.0
# 444370          Uerige Altbier (Classic)           5.0

# %%
## Beer Styles with top ratings
Top_rating_beer_styles = beer_df[['beer_style','review_overall']].groupby('beer_style').review_overall.agg('mean').sort_values(ascending = False).iloc[0:10]
Top_rating_beer_styles = pd.DataFrame(Top_rating_beer_styles)
Top_rating_beer_styles
# Out:
#                                   review_overall
# beer_style
# American Wild Ale                       4.093262
# Gueuze                                  4.086287
# Quadrupel (Quad)                        4.071630
# Lambic - Unblended                      4.048923
# American Double / Imperial Stout        4.029820
# Russian Imperial Stout                  4.023084
# Weizenbock                              4.007969
# American Double / Imperial IPA          3.998017
# Flanders Red Ale                        3.992722
# Rye Beer                                3.981737

# %%
## Beer Styles with top ratings
Top_rating_beer_styles = beer_df[['beer_style','review_overall']].groupby('beer_style').review_overall.agg('mean').sort_values(ascending = False).iloc[0:10]
Top_rating_beer_styles = pd.DataFrame(Top_rating_beer_styles)

## Top 10 beers by Taste
beers_looks_smell = beer_df[['beer_name', 'review_taste']]
beer_looks_smell = beers_looks_smell.groupby('beer_name').aggregate(['max'])
beer_looks_smell = beers_looks_smell.sort_values(by = ['review_taste'],ascending = False).iloc[0:10]

# ask user to input one of the option:

while True:
    try:
        user_input = input('Select one of following option to search best rated Beer: Style, Taste, Abv%: ')
        if user_input == 'Style':
            print (Top_rating_beer_styles)
        elif user_input ==('Taste'):
            print(beer_looks_smell)
        elif user_input == ("Abv%"):
            print()
            break;
        else: 
            print("select correct option")
    except ValueError:
        print("invalid")
        continue
# Out:
# Select one of following option to search best rated Beer: Style, Taste, Abv%: Taste
#                                beer_name  review_taste
# 417039            Great Lakes Eliot Ness           5.0
# 444369          Uerige Altbier (Classic)           5.0
# 444389          Uerige Altbier (Classic)           5.0
# 739729                       Pumpkin Ale           5.0
# 895174  Stone 06.06.06 Vertical Epic Ale           5.0
# 895180  Stone 06.06.06 Vertical Epic Ale           5.0
# 444384          Uerige Altbier (Classic)           5.0
# 895184  Stone 06.06.06 Vertical Epic Ale           5.0
# 739719                       Pumpkin Ale           5.0
# 444370          Uerige Altbier (Classic)           5.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-9a51436341cb> in <module>
#       4 while True:
#       5     try:
# ...

# %%
## Aroma,taste and Appearances by top ratings
beer_looks_smell = beer_df[['beer_name', 'review_taste']].groupby('beer_name').aggregate(['max']).sort_values(by = ['review_taste'],ascending = False).iloc[0:10]
beer_looks_smell
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-620e5fba2ef7> in <module>
#       1 ## Aroma,taste and Appearances by top ratings
# ----> 2 beer_looks_smell = beer_df[['beer_name', 'review_taste']].groupby('beer_name').aggregate(['max']).sort_values(by = ['review_taste'],ascending = False).iloc[0:10]
#       3 beer_looks_smell
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5453
#    5454             by = by[0]
# -> 5455             k = self._get_label_or_level_values(by, axis=axis)
#    5456
#    5457             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1697
#    1698             label_axis_name = "column" if axis == 0 else "index"
# ...

# %%
Top_rating_beer_styles = beer_df[['beer_style','review_overall']].groupby('beer_style').review_overall.agg('mean').sort_values(ascending = False).iloc[0:10]
Top_rating_beer_styles = pd.DataFrame(Top_rating_beer_styles)

user_input = input('Select one of following option to search best rated Beer: Style, Taste, Abv%: '
if user_input == ('Style'):
    print (Top_rating_beer_styles)
elif user_inout = ('Taste'):
    print("something")
